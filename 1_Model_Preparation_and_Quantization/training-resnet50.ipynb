# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.models as models
from torch.utils.data import random_split
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import multiprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# **KHỞI TẠO MÔ HÌNH**

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassification(nn.Module):  
    def training_step(self, batch):  
        images, labels = batch
        out = self(images) 
        loss = F.cross_entropy(out, labels)
        return loss

    def validating(self, batch):
        images, labels = batch
        out = self(images)
        loss = F.cross_entropy(out, labels)
        acc = accuracy(out, labels)
        return {'Validation Loss': loss.detach(), 'Validation Accuracy': acc}

    def validating_epoch_final(self, outputs):
        batch_loss = [x['Validation Loss'] for x in outputs] 
        # each batch of the validation data
        epoch_loss = torch.stack(batch_loss).mean() 
        batch_accuracy = [x['Validation Accuracy'] for x in outputs]
        epoch_accuracy = torch.stack(batch_accuracy).mean()
        return {'Validation Loss': epoch_loss.item(), 'Validation Accuracy': epoch_accuracy.item()}

    def epoch_final(self, epoch, result):
        print("Epoch [{}], Training Loss: {:.4f}, Validation Loss: {:.4f}, Validation Accuracy: {:.4f}"
              .format(epoch + 1, result['Training Loss'], result['Validation Loss'], result['Validation Accuracy']))

# %% [markdown]
# **SỬ DỤNG KIẾN TRÚC ResNet50 CHO VIỆC PHÂN LOẠI**

# %%
class ResNet(ImageClassification):
    def __init__(self):
        super().__init__()
        # Using ResNet50 pretrained model
        self.network = models.resnet50(weights="ResNet50_Weights.DEFAULT")
        features = self.network.fc.in_features
        self.network.fc = nn.Linear(features, len(garbage_classes))

    def forward(self, image):
        return torch.sigmoid(self.network(image))

    def training_step(self, batch):
        images, labels = batch  
        out = self(images) 
        loss = F.cross_entropy(out, labels)
        return loss

    def epoch_final(self, epoch, result):
        print("Epoch [{}], Training Loss: {:.4f}, Validation Loss: {:.4f}, Validation Accuracy: {:.4f}"
              .format(epoch + 1, result['Train Loss'], result['Validation Loss'], result['Validation Accuracy']))

# %% [markdown]
# **THIẾT LẬP HÀM XUẤT CÁC THÔNG SỐ KẾT QUẢ**

# %%
def export_classification_metrics(model, dataloader, classes):
    model.eval()  # Set model to evaluation mode
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in dataloader:
            images, labels = batch
            images = move_to_gpu(images, device)
            labels = labels.to(device)  
            outputs = model(images)
            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())  
            all_labels.extend(labels.cpu().numpy()) 

    for i, class_name in enumerate(classes):
        class_labels = [1 if label == i else 0 for label in all_labels]
        class_preds = [1 if pred == i else 0 for pred in all_preds]
        
        accuracy = accuracy_score(class_labels, class_preds) * 100
        precision = precision_score(class_labels, class_preds, zero_division=0) * 100
        recall = recall_score(class_labels, class_preds, zero_division=0) * 100
        f1 = f1_score(class_labels, class_preds, zero_division=0) * 100
        
        print(f'{class_name}, accuracy: {accuracy:.2f}%, precision: {precision:.2f}%, recall: {recall:.2f}%, F1 score: {f1:.2f}%')

# %% [markdown]
# **THIẾT LẬP EARLY STOPPPING**

# %%
class EarlyStopping:
    def __init__(self, patience=5, verbose=False, restore_best_weights=True):
        self.patience = patience
        self.verbose = verbose
        self.best_loss = float('inf')
        self.counter = 0
        self.early_stop = False
        self.restore_best_weights = restore_best_weights
        self.best_model_weights = None

    def __call__(self, val_loss, model):
        if val_loss < self.best_loss:
            self.best_loss = val_loss
            self.counter = 0
            if self.restore_best_weights:
                self.best_model_weights = model.state_dict().copy()
            if self.verbose:
                print(f'Validation loss improved: {val_loss:.4f}')
        else:
            self.counter += 1
            if self.verbose:
                print(f'Validation loss did not improve: {val_loss:.4f}')
            if self.counter >= self.patience:
                self.early_stop = True
                if self.restore_best_weights and self.best_model_weights is not None:
                    model.load_state_dict(self.best_model_weights)
                    if self.verbose:
                        print("Restored best model weights.")

# %% [markdown]
# **THIẾT LẬP HÀM ĐO HIỆU SUẤT CHÍNH XÁC GIỮA CÁC LOẠI RÁC**

# %%
def plot_accuracy_per_class(model, dataloader, classes):
    model.eval()  # Set model to evaluation mode
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in dataloader:
            images, labels = batch
            images = move_to_gpu(images, device)
            labels = labels.to(device)

            outputs = model(images)
            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy()) 
            all_labels.extend(labels.cpu().numpy())

    accuracies = []
    for i, class_name in enumerate(classes):
        class_labels = [1 if label == i else 0 for label in all_labels]
        class_preds = [1 if pred == i else 0 for pred in all_preds]

        accuracy = accuracy_score(class_labels, class_preds) * 100
        accuracies.append(accuracy)

    plt.bar(classes, accuracies)
    plt.xlabel('Classes')
    plt.ylabel('Accuracy (%)')
    plt.title('Accuracy per Class')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# **LOAD BỘ DỮ LIỆU TRASHNET**

# %%
directory = 'kaggle/input/trashnet/dataset-resized'
global garbage_classes
garbage_classes = os.listdir(directory)
print(garbage_classes)
# Out:
# ['paper', 'metal', 'trash', 'plastic', 'glass', 'cardboard']

# %% [markdown]
# **BIẾN ĐỔI BỘ DỮ LIỆU**

# %%
# Import Transforms để chỉnh sửa ảnh
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

# Resize ảnh về kích thước 224x224 pixels và transform thành Tensor
transformations = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
])

# Load bộ dữ liệu và áp dụng transformations
dataset = ImageFolder(directory, transform=transformations)

# %% [markdown]
# **HIỂN THỊ ẢNH NGẪU NGHIÊN VỚI LABEL ĐỂ TEST BỘ DỮ LIỆU**

# %%
def display_test(image, label):
    print("Label:", dataset.classes[label], "(Class No: " + str(label) + ")")
    plt.imshow(image.permute(1, 2, 0))
    plt.show()

# Hiển thị ảnh ngẫu nhiên từ bộ dữ liệu
image, label = dataset[random.randint(0, len(dataset))]
display_test(image, label)
# Out:
# Label: paper (Class No: 3)

# %% [markdown]
# **THIẾT LẬP SEED NGẪU NHIÊN PHỤC VỤ CHO VIỆC TÁI TẠO**

# %%
random_seed = 43
torch.manual_seed(random_seed)

# %% [markdown]
# **CHIA BỘ DỮ LIỆU & THIẾT LẬP BATCH SIZE**

# %%
# Chia bộ dữ liệu thành các tập train, validate, và test
train_size = int(0.6 * len(dataset))  # 60% bộ dữ liệu
val_size = int(0.2 * len(dataset))  # 20% bộ dữ liệu
test_size = len(dataset) - train_size - val_size  # 20% bộ dữ liệu còn lại
train_data, val_data, test_data = random_split(dataset, [train_size, val_size, test_size])
from torch.utils.data.dataloader import DataLoader
batch_size = 32

# %% [markdown]
# **THIẾT LẬP DATALOADERS**

# %%
train = DataLoader(train_data, batch_size, shuffle=True, num_workers=4, pin_memory=True)
validation = DataLoader(val_data, batch_size * 2, num_workers=4, pin_memory=True)

# %% [markdown]
# **BATCH VISUALIZATION**

# %%
from torchvision.utils import make_grid
def batch_visualization(data):
    for image, labels in data:
        fig, ax = plt.subplots(figsize=(14, 14))
        ax.set_xticks([]);
        ax.set_yticks([])
        ax.imshow(make_grid(image, nrow=16).permute(1, 2, 0))
        plt.show()
        break

batch_visualization(train)
model = ResNet()

# Port model sang GPU
def get_default_device():
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
device = get_default_device()

# Chuyển model sang GPU
def move_to_gpu(data, device):
    if isinstance(data, (list, tuple)):
        return [move_to_gpu(x, device) for x in data]
    return data.to(device, non_blocking=True)

# DataLoading Class
class DataLoad():
    def __init__(self, data, device):
        self.data = data
        self.device = get_default_device()

    def __iter__(self):
        for batch in self.data:
            yield move_to_gpu(batch, self.device)

    def __len__(self):
        return len(self.data)

device = get_default_device()
print('Processing via:', device)  # Note: Nếu output trả về cuda, thì có thể thực hiện huấn luyện qua GPU

train = DataLoad(train, device)
validation = DataLoad(validation, device)
move_to_gpu(model, device)
# Out:
# Processing via: cuda
# ResNet(
#   (network): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=2048, out_features=6, bias=True)
#   )
# )

# %% [markdown]
# **HUẤN LUYỆN MÔ HÌNH**

# %%
@torch.no_grad()
def evaluate(model, validator):
    model.eval()
    outputs = [model.validating(batch) for batch in validator]
    return model.validating_epoch_final(outputs)

def opt(epochs, learning_rate, model, train_loader, validator, opt_func=torch.optim.SGD, patience = 5):
    training_history = []  # List dùng để chứa lịch sử huấn luyện
    optimizer = opt_func(model.parameters(), learning_rate)
    early_stopping = EarlyStopping(patience=patience, verbose=True)  # Thiết lập early stopping

    for epoch in range(epochs):
        model.train()  
        train_loss = []  # List dùng để lưu training loss
        for batch in train_loader:
            loss = model.training_step(batch)  # Tính toán độ loss
            train_loss.append(loss)  # Thêm loss vào danh sách
            loss.backward()  # Thực hiện truyền ngược (Backpropagate)
            optimizer.step()  # Cập nhật các tham số bằng cách sử dụng optimizer
            optimizer.zero_grad()  # Đặt lại gradient về 0 cho batch tiếp theo

        # Giai đoạn Validation
        result = evaluate(model, validator)  # Đánh giá mô hình trên tập xác thực
        result['Train Loss'] = torch.stack(train_loss).mean().item()  # Tinh toán trung bình của training loss
        model.epoch_final(epoch, result)  # Gọi phương thức epoch_final trên mô hình
        training_history.append(result)  # Thêm kết quả vào lịch sử huấn luyện
        
        # Kiểm tra early stopping
        early_stopping(result['Validation Loss'], model)
        if early_stopping.early_stop:
            print("Early stopping triggered.")
            break  # Dừng việc huấn luyện nếu thỏa điều kiện kích hoạt early stopping

    return training_history

model = move_to_gpu(ResNet(), device)
evaluate(model, validation)
# Out:
# {'Validation Loss': 1.7872473001480103,
#  'Validation Accuracy': 0.17280016839504242}

# %% [markdown]
# **THIẾT LẬP HYPERPARAMETERS**

# %%
epoch = 1
optimizer = torch.optim.Adam
learning_rate = 0.00005
patience = 3  # Số epoch chờ để xem tình hình cải thiện của mô hình trước khi dừng huấn luyện
model_history = opt(epoch, learning_rate, model, train, validation, optimizer, patience)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 5
#       3 learning_rate = 0.00005
#       4 patience = 3  # Số epoch chờ để xem tình hình cải thiện của mô hình trước khi dừng huấn luyện
# ----> 5 model_history = opt(epoch, learning_rate, model, train, validation, optimizer, patience)
#
# Cell In[42], line 18, in opt(epochs, learning_rate, model, train_loader, validator, opt_func, patience)
#      16 loss = model.training_step(batch)  # Tính toán độ loss
#      17 train_loss.append(loss)  # Thêm loss vào danh sách
# ---> 18 loss.backward()  # Thực hiện truyền ngược (Backpropagate)
#      19 optimizer.step()  # Cập nhật các tham số bằng cách sử dụng optimizer
#      20 optimizer.zero_grad()  # Đặt lại gradient về 0 cho batch tiếp theo
#
# File ~/.local/lib/python3.10/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/.local/lib/python3.10/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/.local/lib/python3.10/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# **VẼ BIỂU ĐỒ ACCURACY VS EPOCHS & LOSS VS EPOCHS**

# %%
def plot_accuracy(model_history):
    accuracies = [x['Validation Accuracy'] for x in model_history]
    plt.plot(accuracies, '-x')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Accuracy vs Epochs')
    plt.show()
plot_accuracy(model_history)

def plot_loss(model_history):
    train_loss = [x.get('Train Loss') for x in model_history]
    validation_loss = [x['Validation Loss'] for x in model_history]
    plt.plot(train_loss, '-bx')
    plt.plot(validation_loss, '-rx')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs Epochs')
    plt.show()
plot_loss(model_history)

# %% [markdown]
# **XUẤT CÁC THÔNG SỐ KẾT QUẢ VÀ HIỆU SUẤT CHÍNH XÁC GIỮA CÁC LOẠI RÁC**

# %%
export_classification_metrics(model, validation, garbage_classes)
plot_accuracy_per_class(model, validation, garbage_classes)
# Out:
# paper, accuracy: 95.45%, precision: 84.62%, recall: 80.88%, F1 score: 82.71%
# metal, accuracy: 88.51%, precision: 80.56%, recall: 70.16%, F1 score: 75.00%
# trash, accuracy: 91.09%, precision: 83.67%, recall: 52.56%, F1 score: 64.57%
# plastic, accuracy: 89.70%, precision: 70.97%, recall: 94.02%, F1 score: 80.88%
# glass, accuracy: 85.94%, precision: 60.94%, recall: 78.79%, F1 score: 68.72%
# cardboard, accuracy: 96.24%, precision: 0.00%, recall: 0.00%, F1 score: 0.00%

# %% [markdown]
# **VẼ CONFUSION MATRIX**

# %%
def plot_confusion_matrix(model, dataloader, classes):
    model.eval() 
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in dataloader:
            images, labels = batch
            images = move_to_gpu(images, device)
            labels = labels.to(device)

            outputs = model(images)
            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())  
            all_labels.extend(labels.cpu().numpy()) 

    # Tạo confusion matrix
    cm = confusion_matrix(all_labels, all_preds)
    cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100  # Normalize to get percentages
    disp = ConfusionMatrixDisplay(confusion_matrix=cm_percentage, display_labels=classes)

    # Vẽ confusion matrix
    plt.figure(figsize=(10, 10))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title("Confusion Matrix")
    plt.show()
plot_confusion_matrix(model, validation, garbage_classes)

# %% [markdown]
# **TRỰC QUAN HÓA CÁC PREDICTIONS**

# %%
def predict(image, model):
    xb = move_to_gpu(image.unsqueeze(0), device)
    # Nhận dự đoán từ mô hình
    yb = model(xb)
    # Chọn index với xác xuất cao nhất
    _, preds = torch.max(yb, dim=1)
    # Truy xuất class label
    return dataset.classes[preds[0].item()]

# %% [markdown]
# **TESTING NO.1**

# %%
img, label = random.choice(dataset)
plt.imshow(img.permute(1, 2, 0))
print('Testing No.1 - Class:', dataset.classes[label], ', Predicted Class:', predict(img, model))
plt.title('Testing No.1')
plt.show()
# Out:
# Testing No.1 - Class: plastic , Predicted Class: paper

# %% [markdown]
# **TESTING NO.2**

# %%
img, label = random.choice(dataset)
plt.imshow(img.permute(1, 2, 0))
print('Testing No.2 - Class:', dataset.classes[label], ', Predicted Class:', predict(img, model))
plt.title('Testing No.2')
plt.show()
# Out:
# Testing No.2 - Class: metal , Predicted Class: metal

# %% [markdown]
# **TESTING NO.3**

# %%
img, label = random.choice(dataset)
plt.imshow(img.permute(1, 2, 0)) 
print('Testing No.3 - Class:', dataset.classes[label], ', Predicted Class:', predict(img, model))
plt.title('Testing No.3')
plt.show()
# Out:
# Testing No.3 - Class: metal , Predicted Class: plastic

# %% [markdown]
# **LƯU MÔ HÌNH**

# %%
# FILE = "kaggle/output/ResnetModel.pth"
# model_scripted = torch.jit.script(model)
# torch.jit.save(model_scripted, FILE)
torch.save(model.state_dict(), 'kaggle/output/ResnetModel.pth')

# %% [markdown]
# # Create and Save a Simple PyTorch Model

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import hls4ml
import numpy as np
import pprint

# Example model definition (using ResNet50 as in your code)
class ResNet(nn.Module):
    def __init__(self, num_classes):
        super(ResNet, self).__init__()
        # Use a pretrained ResNet50 and replace the final fully-connected layer.
        self.network = models.resnet50(weights="ResNet50_Weights.DEFAULT")
        features = self.network.fc.in_features
        self.network.fc = nn.Linear(features, num_classes)
        # Replace AdaptiveAvgPool2d with a fixed average pooling (kernel size 7) for fixed input sizes
        self.network.avgpool = nn.AvgPool2d(kernel_size=7)

    def forward(self, x):
        # You may use a sigmoid (or softmax) at the end if needed.
        return torch.sigmoid(self.network(x))

# Suppose you have a list of class names (garbage_classes) from your dataset:
# garbage_classes = os.listdir(your_data_directory)
num_classes = len(garbage_classes)

# Instantiate your model and load trained weights
model = ResNet(num_classes)
# Load your trained model weights (adjust the path as needed)
model.load_state_dict(torch.load('kaggle/output/ResnetModel.pth', map_location='cpu'))
model.eval()

# Define the input shape without the batch dimension (channels, height, width)
input_shape = (3, 224, 224)

# Create an HLS4ML configuration from your PyTorch model.
config = hls4ml.utils.config_from_pytorch_model(
    model,
    input_shape=input_shape,
    granularity='name',                # 'name' granularity gives you per-layer control
    default_precision='ap_fixed<16,6>',  # Use fixed-point for better FPGA performance
    backend='Vitis'                    # Choose the backend; e.g., Vitis for Xilinx devices
)

# Optionally, adjust configuration parameters (for example, the reuse factor)
config['Model']['ReuseFactor'] = 16
if 'HLSConfig' not in config:
    config['HLSConfig'] = {}
config['HLSConfig']['WriteTxtFile'] = False

print("-----------------------------------")
print("Configuration")
pprint.pprint(config)
print("-----------------------------------")

config['Part'] = 'xck26-sfvc784-2LV-c'  # Change this to a part available in your Vitis installation
# Convert the PyTorch model to an HLS4ML model.
hls_model = hls4ml.converters.convert_from_pytorch_model(
    model,
    hls_config=config,
    input_shape=input_shape,
    output_dir='hls4ml_project',  # Directory where the HLS project will be generated
    part='xck26-sfvc784-2LV-c',
    backend='Vitis'
)


hls_model.write()
# Out:
# 2025-02-10 01:43:08.359234: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-10 01:43:08.400798: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-10 01:43:08.609380: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 01:43:08.609430: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 01:43:08.610683: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-10 01:43:08.721790: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-10 01:43:09.516482: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# -----------------------------------
# Configuration
# {'HLSConfig': {'WriteTxtFile': False},
#  'InputShape': (3, 224, 224),
#  'LayerName': {'add': {'Precision': {'result': 'auto'},
#                        'ReuseFactor': 1,
#                        'Trace': False},
#                'add_1': {'Precision': {'result': 'auto'},
#                          'ReuseFactor': 1,
#                          'Trace': False},
#                'add_10': {'Precision': {'result': 'auto'},
#                           'ReuseFactor': 1,
#                           'Trace': False},
#                'add_11': {'Precision': {'result': 'auto'},
#                           'ReuseFactor': 1,
#                           'Trace': False},
#                'add_12': {'Precision': {'result': 'auto'},
#                           'ReuseFactor': 1,
#                           'Trace': False},
#                'add_13': {'Precision': {'result': 'auto'},
#                           'ReuseFactor': 1,
#                           'Trace': False},
#                'add_14': {'Precision': {'result': 'auto'},
#                           'ReuseFactor': 1,
#                           'Trace': False},
#                'add_15': {'Precision': {'result': 'auto'},
#                           'ReuseFactor': 1,
#                           'Trace': False},
#                'add_2': {'Precision': {'result': 'auto'},
#                          'ReuseFactor': 1,
#                          'Trace': False},
#                'add_3': {'Precision': {'result': 'auto'},
#                          'ReuseFactor': 1,
#                          'Trace': False},
#                'add_4': {'Precision': {'result': 'auto'},
#                          'ReuseFactor': 1,
#                          'Trace': False},
#                'add_5': {'Precision': {'result': 'auto'},
#                          'ReuseFactor': 1,
#                          'Trace': False},
#                'add_6': {'Precision': {'result': 'auto'},
#                          'ReuseFactor': 1,
#                          'Trace': False},
#                'add_7': {'Precision': {'result': 'auto'},
#                          'ReuseFactor': 1,
#                          'Trace': False},
#                'add_8': {'Precision': {'result': 'auto'},
#                          'ReuseFactor': 1,
#                          'Trace': False},
#                'add_9': {'Precision': {'result': 'auto'},
#                          'ReuseFactor': 1,
#                          'Trace': False},
#                'flatten': {'Precision': {'result': 'auto'}, 'Trace': False},
#                'network_avgpool': {'ConvImplementation': 'LineBuffer',
#                                    'Precision': {'accum': 'auto',
#                                                  'result': 'auto'},
#                                    'ReuseFactor': 1,
#                                    'Trace': False},
#                'network_bn1': {'Precision': {'bias': 'auto',
#                                              'result': 'auto',
#                                              'scale': 'auto'},
#                                'ReuseFactor': 1,
#                                'Trace': False},
#                'network_conv1': {'ConvImplementation': 'LineBuffer',
#                                  'ParallelizationFactor': 1,
#                                  'Precision': {'accum': 'auto',
#                                                'bias': 'auto',
#                                                'result': 'auto',
#                                                'weight': 'auto'},
#                                  'ReuseFactor': 1,
#                                  'Trace': False},
#                'network_fc': {'Precision': {'accum': 'auto',
#                                             'bias': 'auto',
#                                             'result': 'auto',
#                                             'weight': 'auto'},
#                               'ReuseFactor': 1,
#                               'Trace': False},
#                'network_layer1_0_bn1': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer1_0_bn2': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer1_0_bn3': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer1_0_conv1': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer1_0_conv2': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer1_0_conv3': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer1_0_downsample_0': {'ConvImplementation': 'LineBuffer',
#                                                  'ParallelizationFactor': 1,
#                                                  'Precision': {'accum': 'auto',
#                                                                'bias': 'auto',
#                                                                'result': 'auto',
#                                                                'weight': 'auto'},
#                                                  'ReuseFactor': 1,
#                                                  'Trace': False},
#                'network_layer1_0_downsample_1': {'Precision': {'bias': 'auto',
#                                                                'result': 'auto',
#                                                                'scale': 'auto'},
#                                                  'ReuseFactor': 1,
#                                                  'Trace': False},
#                'network_layer1_0_relu': {'Precision': {'result': 'auto',
#                                                        'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                          'ReuseFactor': 1,
#                                          'TableSize': 1024,
#                                          'Trace': False},
#                'network_layer1_0_relu_1': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer1_0_relu_2': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer1_1_bn1': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer1_1_bn2': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer1_1_bn3': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer1_1_conv1': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer1_1_conv2': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer1_1_conv3': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer1_1_relu': {'Precision': {'result': 'auto',
#                                                        'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                          'ReuseFactor': 1,
#                                          'TableSize': 1024,
#                                          'Trace': False},
#                'network_layer1_1_relu_1': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer1_1_relu_2': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer1_2_bn1': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer1_2_bn2': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer1_2_bn3': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer1_2_conv1': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer1_2_conv2': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer1_2_conv3': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer1_2_relu': {'Precision': {'result': 'auto',
#                                                        'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                          'ReuseFactor': 1,
#                                          'TableSize': 1024,
#                                          'Trace': False},
#                'network_layer1_2_relu_1': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer1_2_relu_2': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer2_0_bn1': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer2_0_bn2': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer2_0_bn3': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer2_0_conv1': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer2_0_conv2': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer2_0_conv3': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer2_0_downsample_0': {'ConvImplementation': 'LineBuffer',
#                                                  'ParallelizationFactor': 1,
#                                                  'Precision': {'accum': 'auto',
#                                                                'bias': 'auto',
#                                                                'result': 'auto',
#                                                                'weight': 'auto'},
#                                                  'ReuseFactor': 1,
#                                                  'Trace': False},
#                'network_layer2_0_downsample_1': {'Precision': {'bias': 'auto',
#                                                                'result': 'auto',
#                                                                'scale': 'auto'},
#                                                  'ReuseFactor': 1,
#                                                  'Trace': False},
#                'network_layer2_0_relu': {'Precision': {'result': 'auto',
#                                                        'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                          'ReuseFactor': 1,
#                                          'TableSize': 1024,
#                                          'Trace': False},
#                'network_layer2_0_relu_1': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer2_0_relu_2': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer2_1_bn1': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer2_1_bn2': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer2_1_bn3': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer2_1_conv1': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer2_1_conv2': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer2_1_conv3': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer2_1_relu': {'Precision': {'result': 'auto',
#                                                        'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                          'ReuseFactor': 1,
#                                          'TableSize': 1024,
#                                          'Trace': False},
#                'network_layer2_1_relu_1': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer2_1_relu_2': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer2_2_bn1': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer2_2_bn2': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer2_2_bn3': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer2_2_conv1': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer2_2_conv2': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer2_2_conv3': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer2_2_relu': {'Precision': {'result': 'auto',
#                                                        'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                          'ReuseFactor': 1,
#                                          'TableSize': 1024,
#                                          'Trace': False},
#                'network_layer2_2_relu_1': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer2_2_relu_2': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer2_3_bn1': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer2_3_bn2': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer2_3_bn3': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer2_3_conv1': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer2_3_conv2': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer2_3_conv3': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer2_3_relu': {'Precision': {'result': 'auto',
#                                                        'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                          'ReuseFactor': 1,
#                                          'TableSize': 1024,
#                                          'Trace': False},
#                'network_layer2_3_relu_1': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer2_3_relu_2': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer3_0_bn1': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer3_0_bn2': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer3_0_bn3': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer3_0_conv1': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer3_0_conv2': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer3_0_conv3': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer3_0_downsample_0': {'ConvImplementation': 'LineBuffer',
#                                                  'ParallelizationFactor': 1,
#                                                  'Precision': {'accum': 'auto',
#                                                                'bias': 'auto',
#                                                                'result': 'auto',
#                                                                'weight': 'auto'},
#                                                  'ReuseFactor': 1,
#                                                  'Trace': False},
#                'network_layer3_0_downsample_1': {'Precision': {'bias': 'auto',
#                                                                'result': 'auto',
#                                                                'scale': 'auto'},
#                                                  'ReuseFactor': 1,
#                                                  'Trace': False},
#                'network_layer3_0_relu': {'Precision': {'result': 'auto',
#                                                        'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                          'ReuseFactor': 1,
#                                          'TableSize': 1024,
#                                          'Trace': False},
#                'network_layer3_0_relu_1': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer3_0_relu_2': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer3_1_bn1': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer3_1_bn2': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer3_1_bn3': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer3_1_conv1': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer3_1_conv2': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer3_1_conv3': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer3_1_relu': {'Precision': {'result': 'auto',
#                                                        'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                          'ReuseFactor': 1,
#                                          'TableSize': 1024,
#                                          'Trace': False},
#                'network_layer3_1_relu_1': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer3_1_relu_2': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer3_2_bn1': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer3_2_bn2': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer3_2_bn3': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer3_2_conv1': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer3_2_conv2': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer3_2_conv3': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer3_2_relu': {'Precision': {'result': 'auto',
#                                                        'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                          'ReuseFactor': 1,
#                                          'TableSize': 1024,
#                                          'Trace': False},
#                'network_layer3_2_relu_1': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer3_2_relu_2': {'Precision': {'result': 'auto',
#                                                          'table': 'fixed<18,8,TRN,WRAP,0>'},
#                                            'ReuseFactor': 1,
#                                            'TableSize': 1024,
#                                            'Trace': False},
#                'network_layer3_3_bn1': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer3_3_bn2': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer3_3_bn3': {'Precision': {'bias': 'auto',
#                                                       'result': 'auto',
#                                                       'scale': 'auto'},
#                                         'ReuseFactor': 1,
#                                         'Trace': False},
#                'network_layer3_3_conv1': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer3_3_conv2': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
#                                                         'result': 'auto',
#                                                         'weight': 'auto'},
#                                           'ReuseFactor': 1,
#                                           'Trace': False},
#                'network_layer3_3_conv3': {'ConvImplementation': 'LineBuffer',
#                                           'ParallelizationFactor': 1,
#                                           'Precision': {'accum': 'auto',
#                                                         'bias': 'auto',
# ...
# Layer name: network_layer3_3_bn1, layer type: BatchNormalization, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_3_relu, layer type: Activation, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_3_conv2, layer type: Conv2D, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_3_bn2, layer type: BatchNormalization, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_3_relu_1, layer type: Activation, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_3_conv3, layer type: Conv2D, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_3_bn3, layer type: BatchNormalization, input shape: [[None, 1024, 14, 14]]
# Layer name: add_10, layer type: Merge, input shape: [[None, 1024, 14, 14], [None, 1024, 14, 14]]
# Layer name: network_layer3_3_relu_2, layer type: Activation, input shape: [[None, 1024, 14, 14]]
# Layer name: network_layer3_4_conv1, layer type: Conv2D, input shape: [[None, 1024, 14, 14]]
# Layer name: network_layer3_4_bn1, layer type: BatchNormalization, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_4_relu, layer type: Activation, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_4_conv2, layer type: Conv2D, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_4_bn2, layer type: BatchNormalization, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_4_relu_1, layer type: Activation, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_4_conv3, layer type: Conv2D, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_4_bn3, layer type: BatchNormalization, input shape: [[None, 1024, 14, 14]]
# Layer name: add_11, layer type: Merge, input shape: [[None, 1024, 14, 14], [None, 1024, 14, 14]]
# Layer name: network_layer3_4_relu_2, layer type: Activation, input shape: [[None, 1024, 14, 14]]
# Layer name: network_layer3_5_conv1, layer type: Conv2D, input shape: [[None, 1024, 14, 14]]
# Layer name: network_layer3_5_bn1, layer type: BatchNormalization, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_5_relu, layer type: Activation, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_5_conv2, layer type: Conv2D, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_5_bn2, layer type: BatchNormalization, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_5_relu_1, layer type: Activation, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_5_conv3, layer type: Conv2D, input shape: [[None, 256, 14, 14]]
# Layer name: network_layer3_5_bn3, layer type: BatchNormalization, input shape: [[None, 1024, 14, 14]]
# Layer name: add_12, layer type: Merge, input shape: [[None, 1024, 14, 14], [None, 1024, 14, 14]]
# Layer name: network_layer3_5_relu_2, layer type: Activation, input shape: [[None, 1024, 14, 14]]
# Layer name: network_layer4_0_conv1, layer type: Conv2D, input shape: [[None, 1024, 14, 14]]
# Layer name: network_layer4_0_bn1, layer type: BatchNormalization, input shape: [[None, 512, 14, 14]]
# Layer name: network_layer4_0_relu, layer type: Activation, input shape: [[None, 512, 14, 14]]
# Layer name: network_layer4_0_conv2, layer type: Conv2D, input shape: [[None, 512, 14, 14]]
# Layer name: network_layer4_0_bn2, layer type: BatchNormalization, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_0_relu_1, layer type: Activation, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_0_conv3, layer type: Conv2D, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_0_bn3, layer type: BatchNormalization, input shape: [[None, 2048, 7, 7]]
# Layer name: network_layer4_0_downsample_0, layer type: Conv2D, input shape: [[None, 1024, 14, 14]]
# Layer name: network_layer4_0_downsample_1, layer type: BatchNormalization, input shape: [[None, 2048, 7, 7]]
# Layer name: add_13, layer type: Merge, input shape: [[None, 2048, 7, 7], [None, 2048, 7, 7]]
# Layer name: network_layer4_0_relu_2, layer type: Activation, input shape: [[None, 2048, 7, 7]]
# Layer name: network_layer4_1_conv1, layer type: Conv2D, input shape: [[None, 2048, 7, 7]]
# Layer name: network_layer4_1_bn1, layer type: BatchNormalization, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_1_relu, layer type: Activation, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_1_conv2, layer type: Conv2D, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_1_bn2, layer type: BatchNormalization, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_1_relu_1, layer type: Activation, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_1_conv3, layer type: Conv2D, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_1_bn3, layer type: BatchNormalization, input shape: [[None, 2048, 7, 7]]
# Layer name: add_14, layer type: Merge, input shape: [[None, 2048, 7, 7], [None, 2048, 7, 7]]
# Layer name: network_layer4_1_relu_2, layer type: Activation, input shape: [[None, 2048, 7, 7]]
# Layer name: network_layer4_2_conv1, layer type: Conv2D, input shape: [[None, 2048, 7, 7]]
# Layer name: network_layer4_2_bn1, layer type: BatchNormalization, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_2_relu, layer type: Activation, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_2_conv2, layer type: Conv2D, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_2_bn2, layer type: BatchNormalization, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_2_relu_1, layer type: Activation, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_2_conv3, layer type: Conv2D, input shape: [[None, 512, 7, 7]]
# Layer name: network_layer4_2_bn3, layer type: BatchNormalization, input shape: [[None, 2048, 7, 7]]
# Layer name: add_15, layer type: Merge, input shape: [[None, 2048, 7, 7], [None, 2048, 7, 7]]
# Layer name: network_layer4_2_relu_2, layer type: Activation, input shape: [[None, 2048, 7, 7]]
# Layer name: network_avgpool, layer type: AveragePooling2D, input shape: [[None, 2048, 7, 7]]
# Layer name: flatten, layer type: Reshape, input shape: [[None, 2048, 1, 1]]
# Layer name: network_fc, layer type: Dense, input shape: [[None, 2048]]
# Layer name: sigmoid, layer type: Activation, input shape: [[None, 6]]
# Creating HLS model
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer1_0_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer1_0_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer1_0_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer1_0_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer1_0_downsample_0" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer1_0_downsample_0" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer1_1_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer1_1_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer1_1_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer1_1_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer1_2_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer1_2_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer1_2_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer1_2_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer2_0_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer2_0_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer2_0_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer2_0_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer2_0_downsample_0" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer2_0_downsample_0" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer2_1_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer2_1_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer2_1_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer2_1_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer2_2_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer2_2_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer2_2_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer2_2_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer2_3_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer2_3_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer2_3_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer2_3_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_0_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_0_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_0_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_0_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_0_downsample_0" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_0_downsample_0" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_1_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_1_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_1_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_1_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_2_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_2_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_2_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_2_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_3_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_3_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_3_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_3_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_4_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_4_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_4_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_4_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_5_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_5_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer3_5_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer3_5_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer4_0_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer4_0_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer4_0_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer4_0_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer4_0_downsample_0" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer4_0_downsample_0" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer4_1_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer4_1_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer4_1_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer4_1_conv3" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer4_2_conv1" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer4_2_conv1" (PointwiseConv2D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "network_layer4_2_conv3" (PointwiseConv2D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "network_layer4_2_conv3" (PointwiseConv2D)
# Writing HLS project
# Done

# %%
print(hls_model)
# Compile the HLS model (this runs a C-simulation to check correctness)
hls_model.compile()

# You can now run a prediction using a dummy input.
dummy_input = np.random.randn(*input_shape).astype(np.float32)
output = hls_model.predict(dummy_input)
print("HLS4ML model output:", output)
hls_model.build()
# Out:
# <hls4ml.model.graph.ModelGraph object at 0x7f8b1267d780>
# Writing HLS project
# Done

# %%
# hls_model.build()
